# %% [markdown]
# SUPERVISED LEARNING - LinearRegression - Salary prediction(*SANTHOSH U*)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
saldf = pd.read_csv("/content/Salary_Data.csv")

# %%
saldf.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
saldf.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
saldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
saldf.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
inp = saldf[["YearsExperience"]]
out = saldf["Salary"]

# %%
LR = LinearRegression()

# %%
LR.fit(inp, out)
# Out:
# LinearRegression()

# %%
LR.predict([[5]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([73042.01180594])

# %%
plt.scatter(inp, out)
plt.plot(inp, LR.predict(inp))
